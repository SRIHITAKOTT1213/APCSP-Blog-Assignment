# %% [markdown]
# # First Jupyter Notebook
#
#
# - title: Test # 4 Corrections
# - toc: true
# - permalink: /test4/corrections
# - categories: [Other Projects]
# - comments: true

# %% [markdown]
# ### Question 5

# %% [markdown]
# Maybe this is because it comes before the domain? and that's why its called a subdomain?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 7
# I think this makes sense because every device has a different IP address, so it makes sense that it needs and IP in order to be connected to the internet
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 23
# C is the answer because finding the highest 10 grade point averages isn't really a pattern. A pattern would be more of credit card numbers, customers past purchases, and recomending new products based on past purchased products would be examples of patterns.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 27
# I think what it means that this can be reversed, at the end of the answer choice, means that the original image can be RECOVRED, which is definitely a characterstic of lossless data.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 34
# I think this basically means that there is no way to write an algorithm that will work because the problem is unsolvable.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 37
# I just wasn't sure if it had to be run in a reasonable time or a unreasonable time. But the reason it is n^2 steps is because according to the table, for the number of shapes drawn, the steps are appromixamately the same as the the number of shapes drawn squared.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 38
# I guess I got confused by this because simulations aren't meant to be accurate, because there are factors in real life that you can't include in a simulation. But on the other hand, this does make sense because it is a simulation, so it can tell us how to improve before we move the project to real life.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 39
# It keeps going in a loop until it gets 1 and 2. But I don't really understand why the others are possible because  the other answer choices
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 42
# I guess this works because if you go through multiple text files and you get true for more than one text file, then you know more than one text file has that one word you're looking for.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 50
# I thought at first that the second and the third worked. But I think the third one doesn't work because it's taking into regard the days of any month and that can affect the results.
#
# ![image.png](attachment:image.png)
