# %% [markdown]
# # First Jupyter Notebook
#
#
# - title: Big Idea 2 Correction
# - toc: true
# - permalink: /Big/Idea2
# - categories: [Other Projects]
# - comments: true

# %% [markdown]
# **Question #1:** I got this right at first but then changed my answer at the last minute. Basically it is 7 because 2^7 is 128 which over 100 so it works.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Question 19:** D is correct because filtering the data doesn't change the order of the rows.
# ![image.png](attachment:image.png)

# %% [markdown]
# **Question 21:** Filtering both the photographer and the year will remove the unknown variables from the table and that is why B and D are the correct answer
# ![image.png](attachment:image.png)
